# %%
import pandas as pd

# Load dataset
df = pd.read_csv('C:/Users/Asus/Downloads/USA_Housing.csv')


# View first few rows
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05
#
#                   Address
# 0        Imadol, Lalitpur
# 1     Satdobato, Lalitpur
# 2        Imadol, Lalitpur
# 3    Bhaisepati, Lalitpur
# 4  Maharajgunj, Kathmandu

# %%
# List of columns you want to visualize
columns = ['Avg. Area Income', 
           'Avg. Area House Age', 
           'Avg. Area Number of Rooms', 
           'Avg. Area Number of Bedrooms', 
           'Area Population', 
           'Price']

# Set plot style
sns.set(style="whitegrid")
plt.figure(figsize=(16, 10))

# Loop through columns and plot density
for i, col in enumerate(columns, 1):
    plt.subplot(2, 3, i)
    sns.kdeplot(df[col], shade=True, color='skyblue')
    plt.title(f'Density Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# -------------------------------------------------------------
# NameError                   Traceback (most recent call last)
# Cell In[5], line 10
#       2 columns = ['Avg. Area Income',
#       3            'Avg. Area House Age',
#       4            'Avg. Area Number of Rooms',
#       5            'Avg. Area Number of Bedrooms',
#       6            'Area Population',
#       7            'Price']
#       9 # Set plot style
# ---> 10 sns.set(style="whitegrid")
#      11 plt.figure(figsize=(16, 10))
#      13 # Loop through columns and plot density
#
# NameError: name 'sns' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset (ensure this path is correct and file exists)
df = pd.read_csv(r'C:\Users\Asus\Downloads\USA_Housing.csv')

# Columns to plot
columns = ['Avg. Area Income', 
           'Avg. Area House Age', 
           'Avg. Area Number of Rooms', 
           'Avg. Area Number of Bedrooms', 
           'Area Population', 
           'Price']

# Set plot style
sns.set(style="whitegrid")
plt.figure(figsize=(16, 10))

# Create density plots
for i, col in enumerate(columns, 1):
    plt.subplot(2, 3, i)
    sns.kdeplot(df[col], shade=True, color='skyblue')
    plt.title(f'Density Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_8992\888699973.py:23: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], shade=True, color='skyblue')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_8992\888699973.py:23: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], shade=True, color='skyblue')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_8992\888699973.py:23: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], shade=True, color='skyblue')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_8992\888699973.py:23: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'C:\Users\Asus\Downloads\USA_Housing.csv')

# Columns to plot
columns = ['Avg. Area Income', 
           'Avg. Area House Age', 
           'Avg. Area Number of Rooms', 
           'Avg. Area Number of Bedrooms', 
           'Area Population', 
           'Price']

# Set plot style
sns.set(style="whitegrid")
plt.figure(figsize=(16, 10))

# Create density plots using fill instead of shade
for i, col in enumerate(columns, 1):
    plt.subplot(2, 3, i)
    sns.kdeplot(df[col], fill=True, color='skyblue')
    plt.title(f'Density Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Sample data generation (replace with your actual y_test and y_pred)
np.random.seed(42)
y_test = np.random.normal(500000, 150000, 1000)  # Actual prices
y_pred = y_test * 0.9147 + np.random.normal(0, 50000, 1000)  # Simulated 91.47% accurate predictions

# 1. Actual vs Predicted Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--')
plt.xlabel('Actual Prices ($)')
plt.ylabel('Predicted Prices ($)')
plt.title(f'Actual vs Predicted Prices (R² = {r2_score(y_test, y_pred):.2f})')
plt.grid(True)
plt.show()

# 2. Residual Plot
residuals = y_test - y_pred
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_pred, y=residuals, alpha=0.6)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Prices ($)')
plt.ylabel('Residuals ($)')
plt.title('Residual Analysis')
plt.grid(True)
plt.show()

# 3. Error Distribution
plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True, bins=30)
plt.xlabel('Prediction Error ($)')
plt.title('Error Distribution')
plt.grid(True)
plt.show()

# 4. Binned Price Accuracy (Confusion Matrix Style)
price_bins = [0, 200000, 400000, 600000, 800000, float('inf')]
bin_labels = ['<200K', '200-400K', '400-600K', '600-800K', '>800K']

actual_binned = pd.cut(y_test, bins=price_bins, labels=bin_labels)
predicted_binned = pd.cut(y_pred, bins=price_bins, labels=bin_labels)

confusion_matrix = pd.crosstab(
    actual_binned, 
    predicted_binned, 
    rownames=['Actual'], 
    colnames=['Predicted'],
    margins=True
)

plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix.iloc[:-1, :-1], annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Price Range Prediction Accuracy')
plt.show()

# Metrics Table
metrics = {
    'R² Score': r2_score(y_test, y_pred),
    'Adjusted R²': 1 - (1 - r2_score(y_test, y_pred)) * (len(y_test) - 1) / (len(y_test) - 4 - 1),
    'MAE': mean_absolute_error(y_test, y_pred),
    'RMSE': np.sqrt(mean_squared_error(y_test, y_pred)),
    'MAPE': np.mean(np.abs((y_test - y_pred) / y_test)) * 100
}

pd.DataFrame.from_dict(metrics, orient='index', columns=['Value']).style.format("{:.2f}").background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_a95c9_row0_col0, #T_a95c9_row1_col0, #T_a95c9_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a95c9_row2_col0 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_a95c9_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a95c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a95c9_level0_col0" class="col_heading level0 col0" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a95c9_level0_row0" class="row_heading level0 row0" >R² Score</th>
#       <td id="T_a95c9_row0_col0" class="data row0 col0" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_a95c9_level0_row1" class="row_heading level0 row1" >Adjusted R²</th>
#       <td id="T_a95c9_row1_col0" class="data row1 col0" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_a95c9_level0_row2" class="row_heading level0 row2" >MAE</th>
# ...
